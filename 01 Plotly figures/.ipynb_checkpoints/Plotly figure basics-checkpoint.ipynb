, -0.31154521331169593, -1.198266155174907, 1.6180829950038127, 0.8335795939685862, -0.19253861892470053, 1.7883633500688678, -0.44979713996081855, 2.230567747924841, -0.6747740988502191, -1.0599090914561209, -0.08411627118615639, -1.1933073883443848, -1.9655315959926214, -1.9561463665415748, 0.6285991833495405, -1.076931558458624, -0.8332710035747369, -2.4094370285066664, 1.3540339714458185, -1.6810088979924989, 0.6670941908731325, -0.347464469631186, 0.3754171077299921, -1.9179596032975883, -0.5475318302152393, 0.4981302248730179, -0.36873259816696685, -0.8814404749110394, 0.13382606698691604, 2.4727434692756134, -0.98990042743976, -0.12377023779122444, 0.6435519214970394, -0.8437796614345214, 0.0025741526420830422, -0.44727104680918867, -1.1489951881900902, 1.0404002457282857, 0.0817644729451322, -1.4842064591135438, -0.608602673543713, -0.06121358703309537, -1.0829356436077713, -0.4591567321291795, -1.615238712401105, 0.5416647886743603, 1.2617938262349135, 0.4593199171410423, 0.5116065913595986, -0.936841418999696, -0.7412534371778104, -0.47108124820843805, 0.8792726823124216, -1.5571613855457294, 1.4726326728297598, 0.20195763085661259, -0.4861961799479886, -1.0122134833587881, -0.6187749484109348, -0.5145506963592379, 0.06550801953731256, -1.373718 ...

# %%
# Simple bar chart
x_values=['male', 'female']
y_values=[5, 7]
fig = [go.Bar(x=x_values, y=y_values)] 
iplot(fig)
# Out:
# <div>
#
#
#             <div id="7ea3306f-5567-4ae2-86ec-73f07b674e64" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7ea3306f-5567-4ae2-86ec-73f07b674e64")) {
#                     Plotly.newPlot(
#                         '7ea3306f-5567-4ae2-86ec-73f07b674e64',
#                         [{"type": "bar", "uid": "6612c4c6-9752-4ce7-9814-364542d1da9f", "x": ["male", "female"], "y": [5, 7]}],
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('7ea3306f-5567-4ae2-86ec-73f07b674e64');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
# Pie chart 
gas = ['Oxygen','Hydrogen','Carbon Dioxide','Nitrogen']
volume = [4500,2500,1053,500]

fig = [go.Pie(labels=gas, values=volume)]
iplot(fig)
# Out:
# <div>
#
#
#             <div id="3f425670-a059-4378-98ff-a1080d47a6c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3f425670-a059-4378-98ff-a1080d47a6c5")) {
#                     Plotly.newPlot(
#                         '3f425670-a059-4378-98ff-a1080d47a6c5',
#                         [{"labels": ["Oxygen", "Hydrogen", "Carbon Dioxide", "Nitrogen"], "type": "pie", "uid": "e1f07b12-dad2-4207-9aa8-f4ae9052e06f", "values": [4500, 2500, 1053, 500]}],
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('3f425670-a059-4378-98ff-a1080d47a6c5');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
# Scatter plot of 1000 random points
random_x = np.random.randn(1000)
random_y = np.random.randn(1000)

# Create a trace
trace = go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers'
)

fig = [trace]
iplot(fig)
# Out:
# <div>
#
#
#             <div id="11608dfb-12e1-4dcc-bc7c-b7afb1bb0122" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("11608dfb-12e1-4dcc-bc7c-b7afb1bb0122")) {
#                     Plotly.newPlot(
#                         '11608dfb-12e1-4dcc-bc7c-b7afb1bb0122',
# %% [markdown]
# ## How it works

# %%
# Define our data as lists.
x_values=['giraffes', 'orangutans', 'monkeys']
y_values=[20, 14, 23]

# %%
# Plotly's 'go.Bar' function will create a dictionary of our x and y values, with predefined keys. 
go.Bar(x=x_values, y=y_values)
# Out:
# Bar({
#     'x': ['giraffes', 'orangutans', 'monkeys'], 'y': [20, 14, 23]
# })

# %%
# You'll always have to place your data dictionary inside a list
# because it will become a component of a larger dictionary once we read it into Plotly's 'go.Figure' function
[go.Bar(x=x_values, y=y_values)]
# Out:
# [Bar({
#      'x': ['giraffes', 'orangutans', 'monkeys'], 'y': [20, 14, 23]
#  })]

# %%
# Define our axis labels as dictionaries.
x_title = {'title': 'Type of animal'} 
y_title = {'title': 'Number in the zoo'} 
print(x_title, y_title)
# Out:
# {'title': 'Type of animal'} {'title': 'Number in the zoo'}

# %%
# You can do the same thing using Python's 'dict' function
x_title = dict(title = 'Type of animal')
y_title = dict(title = 'Number in the zoo')
print(x_title, y_title)
# Out:
# {'title': 'Type of animal'} {'title': 'Number in the zoo'}

# %%
# Plotly's 'go.Layout' function will create a dictionary of our axis labels, with predefined keys.
go.Layout(xaxis=x_title, yaxis=y_title)
# Out:
# Layout({
#     'xaxis': {'title': {'text': 'Type of animal'}}, 'yaxis': {'title': {'text': 'Number in the zoo'}}
# })

# %%
# Plotly's 'go.Figure' function will create a dictionary of our axis labels, with predefined keys.
my_data = [go.Bar(go.Bar(x=x_values, y=y_values))] # Note: We have to put the data dictionary inside a list!
my_layout = go.Layout(xaxis=x_title, yaxis=y_title)
go.Figure(data=my_data, layout=my_layout)
# Out:
# Figure({
#     'data': [{'type': 'bar',
#               'uid': 'a708c2a3-c645-4379-88c4-158774120aee',
#               'x': [giraffes, orangutans, monkeys],
#               'y': [20, 14, 23]}],
#     'layout': {'xaxis': {'title': {'text': 'Type of animal'}}, 'yaxis': {'title': {'text': 'Number in the zoo'}}}
# })

# %%
# Finally, display your figure 
fig = go.Figure(data=my_data, layout=my_layout)
iplot(fig) # inside the Jupyter notebook
plot(fig) # in your browswer
# Out:
# <div>
#
#
#             <div id="9e373576-0711-454f-8270-3447643da9fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9e373576-0711-454f-8270-3447643da9fe")) {
#                     Plotly.newPlot(
#                         '9e373576-0711-454f-8270-3447643da9fe',
#                         [{"type": "bar", "uid": "0b7912ec-2637-4450-be45-f2c79dec890f", "x": ["giraffes", "orangutans", "monkeys"], "y": [20, 14, 23]}],
#                         {"xaxis": {"title": {"text": "Type of animal"}}, "yaxis": {"title": {"text": "Number in the zoo"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('9e373576-0711-454f-8270-3447643da9fe');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# 'temp-plot.html'

# %% [markdown]
# ## Formatting a simple bar chart

# %%
# Adding some layout to the simple chart we saw before
data = [go.Bar(
            x=['giraffes', 'orangutans', 'monkeys'],
            y=[20, 14, 23],
            marker=dict(color='green')
    )]

layout = go.Layout(
    title = 'My favorite animals', # Graph title
    xaxis = dict(title = 'Type of animal'), # x-axis label
    yaxis = dict(title = 'Number in the zoo'), # y-axis label
    
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="8ad57ab4-d8ab-4776-8b01-735ad83d5792" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8ad57ab4-d8ab-4776-8b01-735ad83d5792")) {
#                     Plotly.newPlot(
#                         '8ad57ab4-d8ab-4776-8b01-735ad83d5792',
#                         [{"marker": {"color": "green"}, "type": "bar", "uid": "9d52cf55-f302-4a58-9aa9-bd438fd3ba55", "x": ["giraffes", "orangutans", "monkeys"], "y": [20, 14, 23]}],
#                         {"title": {"text": "My favorite animals"}, "xaxis": {"title": {"text": "Type of animal"}}, "yaxis": {"title": {"text": "Number in the zoo"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('8ad57ab4-d8ab-4776-8b01-735ad83d5792');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
# Grouped bar chart
trace1 = go.Bar(
    x=['giraffes', 'orangutans', 'monkeys'],
    y=[20, 14, 23],
    name='SF Zoo',
    marker=dict(color='rgb(10,10,255)')
)
trace2 = go.Bar(
    x=['giraffes', 'orangutans', 'monkeys'],
    y=[12, 18, 29],
    name='LA Zoo',
    marker=dict(color='rgb(139,0,0)')
)

data = [trace1, trace2]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="c9577f97-dbe2-4ab1-ab9b-5b679652cbfa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c9577f97-dbe2-4ab1-ab9b-5b679652cbfa")) {
#                     Plotly.newPlot(
#                         'c9577f97-dbe2-4ab1-ab9b-5b679652cbfa',
#                         [{"marker": {"color": "rgb(10,10,255)"}, "name": "SF Zoo", "type": "bar", "uid": "ebe77b7c-50e2-4817-ac40-9b9bef0cde75", "x": ["giraffes", "orangutans", "monkeys"], "y": [20, 14, 23]}, {"marker": {"color": "rgb(139,0,0)"}, "name": "LA Zoo", "type": "bar", "uid": "3e151998-9d18-4e76-9503-fe88ca26d191", "x": ["giraffes", "orangutans", "monkeys"], "y": [12, 18, 29]}],
#                         {"barmode": "group"},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('c9577f97-dbe2-4ab1-ab9b-5b679652cbfa');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
# Stacked bar chart
trace1 = go.Bar(
    x=['giraffes', 'orangutans', 'monkeys'],
    y=[20, 14, 23],
    name='SF Zoo',
    textposition = 'auto',
    marker=dict(
        color='lightgreen',
        line=dict(
            color='darkblue',
            width=1.5),
        ),
    opacity=0.6
)
trace2 = go.Bar(
    x=['giraffes', 'orangutans', 'monkeys'],
    y=[12, 18, 29],
    name='LA Zoo',
    textposition = 'auto',
    marker=dict(
        color='lightblue',
        line=dict(
            color='darkblue',
            width=1.5),
        ),
    opacity=0.6
)

data = [trace1, trace2]
layout = go.Layout(
    barmode='stack',
    title = 'My favorite animals', # Graph title
    xaxis = dict(title = 'Type of animal', tickangle=-45), # x-axis label
    yaxis = dict(title = 'Number in the zoo'), # y-axis label
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="bec1310d-a991-410f-88df-22130cadf6af" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bec1310d-a991-410f-88df-22130cadf6af")) {
#                     Plotly.newPlot(
#                         'bec1310d-a991-410f-88df-22130cadf6af',
#                         [{"marker": {"color": "lightgreen", "line": {"color": "darkblue", "width": 1.5}}, "name": "SF Zoo", "opacity": 0.6, "textposition": "auto", "type": "bar", "uid": "fb2a6278-d09e-4373-8461-447c93c95dcc", "x": ["giraffes", "orangutans", "monkeys"], "y": [20, 14, 23]}, {"marker": {"color": "lightblue", "line": {"color": "darkblue", "width": 1.5}}, "name": "LA Zoo", "opacity": 0.6, "textposition": "auto", "type": "bar", "uid": "4edcc100-c40e-4d50-855e-dd343c8828dc", "x": ["giraffes", "orangutans", "monkeys"], "y": [12, 18, 29]}],
#                         {"barmode": "stack", "title": {"text": "My favorite animals"}, "xaxis": {"tickangle": -45, "title": {"text": "Type of animal"}}, "yaxis": {"title": {"text": "Number in the zoo"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('bec1310d-a991-410f-88df-22130cadf6af');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ## Simple scatter plot

# %%
# Create some fake data.
np.random.seed(42)
random_x = np.random.randint(1,101,100)
random_y = np.random.randint(1,101,100)

# %%
# Visualize the data with Plotly Graph Objects library
data = [go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers'
)]

fig =go.Figure(data=data)
iplot(fig) # This will visualize your figure within the Jupyter noteobook
# py.plot(data) # Note: This will publish your figure to the web via Plotly, but requires an account.
# Out:
# <div>
#
#
#             <div id="fbfad150-297d-4dd1-9761-9c966d5d2796" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("fbfad150-297d-4dd1-9761-9c966d5d2796")) {
#                     Plotly.newPlot(
#                         'fbfad150-297d-4dd1-9761-9c966d5d2796',
#                         [{"mode": "markers", "type": "scatter", "uid": "396360ec-daca-4188-9957-af27c86a161f", "x": [52, 93, 15, 72, 61, 21, 83, 87, 75, 75, 88, 100, 24, 3, 22, 53, 2, 88, 30, 38, 2, 64, 60, 21, 33, 76, 58, 22, 89, 49, 91, 59, 42, 92, 60, 80, 15, 62, 62, 47, 62, 51, 55, 64, 3, 51, 7, 21, 73, 39, 18, 4, 89, 60, 14, 9, 90, 53, 2, 84, 92, 60, 71, 44, 8, 47, 35, 78, 81, 36, 50, 4, 2, 6, 54, 4, 54, 93, 63, 18, 90, 44, 34, 74, 62, 100, 14, 95, 48, 15, 72, 78, 87, 62, 40, 85, 80, 82, 53, 24], "y": [26, 89, 60, 41, 29, 15, 45, 65, 89, 71, 9, 88, 1, 8, 88, 63, 11, 81, 8, 35, 35, 33, 5, 41, 28, 7, 73, 72, 12, 34, 33, 48, 23, 62, 88, 37, 99, 44, 86, 91, 35, 65, 99, 47, 78, 3, 1, 5, 90, 14, 27, 9, 79, 15, 90, 42, 77, 51, 63, 96, 52, 96, 4, 94, 23, 15, 43, 29, 36, 13, 32, 71, 59, 86, 28, 66, 42, 45, 62, 57, 6, 28, 28, 44, 84, 30, 62, 75, 92, 89, 62, 97, 1, 27, 62, 77, 3, 70, 72, 27]}],
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('fbfad150-297d-4dd1-9761-9c966d5d2796');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
# Let's add some layout to our data.
data = [go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers',
    marker=dict(
        color='rgb(58,200,225)')
)]
layout = go.Layout(
    title = 'Random Data Scatterplot', # Graph title
    xaxis = dict(title = 'Some random x-values'), # x-axis label
    yaxis = dict(title = 'Some random y-values'), # y-axis label
    hovermode ='closest' # handles multiple points landing on the same vertical
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="2124151c-9816-4ee6-b138-e69e4da50010" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2124151c-9816-4ee6-b138-e69e4da50010")) {
#                     Plotly.newPlot(
#                         '2124151c-9816-4ee6-b138-e69e4da50010',
#                         [{"marker": {"color": "rgb(58,200,225)"}, "mode": "markers", "type": "scatter", "uid": "f7f6683d-fe2e-4c36-a8d4-057b9b67f288", "x": [52, 93, 15, 72, 61, 21, 83, 87, 75, 75, 88, 100, 24, 3, 22, 53, 2, 88, 30, 38, 2, 64, 60, 21, 33, 76, 58, 22, 89, 49, 91, 59, 42, 92, 60, 80, 15, 62, 62, 47, 62, 51, 55, 64, 3, 51, 7, 21, 73, 39, 18, 4, 89, 60, 14, 9, 90, 53, 2, 84, 92, 60, 71, 44, 8, 47, 35, 78, 81, 36, 50, 4, 2, 6, 54, 4, 54, 93, 63, 18, 90, 44, 34, 74, 62, 100, 14, 95, 48, 15, 72, 78, 87, 62, 40, 85, 80, 82, 53, 24], "y": [26, 89, 60, 41, 29, 15, 45, 65, 89, 71, 9, 88, 1, 8, 88, 63, 11, 81, 8, 35, 35, 33, 5, 41, 28, 7, 73, 72, 12, 34, 33, 48, 23, 62, 88, 37, 99, 44, 86, 91, 35, 65, 99, 47, 78, 3, 1, 5, 90, 14, 27, 9, 79, 15, 90, 42, 77, 51, 63, 96, 52, 96, 4, 94, 23, 15, 43, 29, 36, 13, 32, 71, 59, 86, 28, 66, 42, 45, 62, 57, 6, 28, 28, 44, 84, 30, 62, 75, 92, 89, 62, 97, 1, 27, 62, 77, 3, 70, 72, 27]}],
#                         {"hovermode": "closest", "title": {"text": "Random Data Scatterplot"}, "xaxis": {"title": {"text": "Some random x-values"}}, "yaxis": {"title": {"text": "Some random y-values"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('2124151c-9816-4ee6-b138-e69e4da50010');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
data = [go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers',
    marker = dict(      # change the marker style
        size = 12,
        color = 'rgb(51,204,153)',
        symbol = 'pentagon',
        line = dict(
            width = 2,
        )
    )
)]
layout = go.Layout(
    title = 'Random Data Scatterplot', # Graph title
    xaxis = dict(title = 'Some random x-values'), # x-axis label
    yaxis = dict(title = 'Some random y-values'), # y-axis label
    hovermode ='closest' # handles multiple points landing on the same vertical
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="bbb47bb5-914a-42c0-ba5b-5caf2869e246" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bbb47bb5-914a-42c0-ba5b-5caf2869e246")) {
#                     Plotly.newPlot(
#                         'bbb47bb5-914a-42c0-ba5b-5caf2869e246',
#                         [{"marker": {"color": "rgb(51,204,153)", "line": {"width": 2}, "size": 12, "symbol": "pentagon"}, "mode": "markers", "type": "scatter", "uid": "67caa07c-e55d-488a-a271-17c8d88d5959", "x": [52, 93, 15, 72, 61, 21, 83, 87, 75, 75, 88, 100, 24, 3, 22, 53, 2, 88, 30, 38, 2, 64, 60, 21, 33, 76, 58, 22, 89, 49, 91, 59, 42, 92, 60, 80, 15, 62, 62, 47, 62, 51, 55, 64, 3, 51, 7, 21, 73, 39, 18, 4, 89, 60, 14, 9, 90, 53, 2, 84, 92, 60, 71, 44, 8, 47, 35, 78, 81, 36, 50, 4, 2, 6, 54, 4, 54, 93, 63, 18, 90, 44, 34, 74, 62, 100, 14, 95, 48, 15, 72, 78, 87, 62, 40, 85, 80, 82, 53, 24], "y": [26, 89, 60, 41, 29, 15, 45, 65, 89, 71, 9, 88, 1, 8, 88, 63, 11, 81, 8, 35, 35, 33, 5, 41, 28, 7, 73, 72, 12, 34, 33, 48, 23, 62, 88, 37, 99, 44, 86, 91, 35, 65, 99, 47, 78, 3, 1, 5, 90, 14, 27, 9, 79, 15, 90, 42, 77, 51, 63, 96, 52, 96, 4, 94, 23, 15, 43, 29, 36, 13, 32, 71, 59, 86, 28, 66, 42, 45, 62, 57, 6, 28, 28, 44, 84, 30, 62, 75, 92, 89, 62, 97, 1, 27, 62, 77, 3, 70, 72, 27]}],
#                         {"hovermode": "closest", "title": {"text": "Random Data Scatterplot"}, "xaxis": {"title": {"text": "Some random x-values"}}, "yaxis": {"title": {"text": "Some random y-values"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('bbb47bb5-914a-42c0-ba5b-5caf2869e246');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
# Using colorscale
trace1 = go.Scatter(
    y = np.random.randn(500),
    mode='markers',
    marker=dict(
        size=16,
        color = np.random.randn(500), #set color equal to a third variable
        colorscale='Viridis',
        showscale=True
    )
)
data = [trace1]
layout = go.Layout(
    title = 'Random Data Scatterplot', # Graph title
    xaxis = dict(title = 'Some random x-values'), # x-axis label
    yaxis = dict(title = 'Some random y-values'), # y-axis label
    hovermode ='closest' # handles multiple points landing on the same vertical
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="4196e8e7-64eb-4959-bf1f-0a52066a1d27" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4196e8e7-64eb-4959-bf1f-0a52066a1d27")) {
#                     Plotly.newPlot(
#                         '4196e8e7-64eb-4959-bf1f-0a52066a1d27',
#                         [{"marker": {"color": [0.7569886166453519, -0.9221653241776254, 0.8696059201056602, 1.355637858804951, 0.41343490322370086, 1.876795812558066, -0.773789199103573, -1.244654703311417, -1.7787202489042786, 1.496044311489183, 0.6543656563540577, -0.05558467091045507, 0.2799686263198203, -1.1254890472983765, 2.4457519796168263, 0.1292211819752275, 0.10939479460489289, 0.725766623898692, 0.4810092317367132, 0.22388402427913137, -0.7904744554453119, 0.4714683571359957, 1.8820244964750337, 1.3454200461549777, 1.593186626639397, -0.5112156764311852, -0.9896048202585809, -0.12578692009964815, 0.055724912288694604, 1.0941915184709485, -1.6924646297148194, 1.5295503194606137, -0.15800789857898942, -0.42688106994742003, -1.0121043752601675, -1.6548566718657693, 0.8231705839619146, 0.07331796718840389, -1.2899608997410539, -1.295078772063616, -0.3357846992901282, 1.669

    mode = 'markers',
    name = 'markers'
)
trace1 = go.Scatter(
    x = x_values,
    y = y_values,
    mode = 'lines+markers',
    name = 'lines+markers'
)
trace2 = go.Scatter(
    x = x_values,
    y = y_values-5,
    mode = 'lines',
    name = 'lines'
)

# assign traces to data
data = [trace0, trace1, trace2]  
layout = go.Layout(
    title = 'Line chart showing three different modes'
)
# Generate the figure dictionary
fig = go.Figure(data=data,layout=layout)

# Display the figure
iplot(fig)
# Out:
# <div>
#
#
#             <div id="194d66ac-7a05-43d3-b840-ac7a5170d88c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("194d66ac-7a05-43d3-b840-ac7a5170d88c")) {
#                     Plotly.newPlot(
#                         '194d66ac-7a05-43d3-b840-ac7a5170d88c',
#                         [{"mode": "markers", "name": "markers", "type": "scatter", "uid": "e3d68386-561f-4181-9486-8f0b3ef6ab6e", "x": [0.0, 0.010101010101010102, 0.020202020202020204, 0.030303030303030304, 0.04040404040404041, 0.05050505050505051, 0.06060606060606061, 0.07070707070707072, 0.08080808080808081, 0.09090909090909091, 0.10101010101010102, 0.11111111111111112, 0.12121212121212122, 0.13131313131313133, 0.14141414141414144, 0.15151515151515152, 0.16161616161616163, 0.17171717171717174, 0.18181818181818182, 0.19191919191919193, 0.20202020202020204, 0.21212121212121213, 0.22222222222222224, 0.23232323232323235, 0.24242424242424243, 0.25252525252525254, 0.26262626262626265, 0.27272727272727276, 0.2828282828282829, 0.29292929292929293, 0.30303030303030304, 0.31313131313131315, 0.32323232323232326, 0.33333333333333337, 0.3434343434343435, 0.3535353535353536, 0.36363636363636365, 0.37373737373737376, 0.38383838383838387, 0.393939393939394, 0.4040404040404041, 0.4141414141414142, 0.42424242424242425, 0.43434343434343436, 0.4444444444444445, 0.4545454545454546, 0.4646464646464647, 0.4747474747474748, 0.48484848484848486, 0.494949494949495, 0.5050505050505051, 0.5151515151515152, 0.5252525252525253, 0.5353535353535354, 0.5454545454545455, 0.5555555555555556, 0.5656565656565657, 0.5757575757575758, 0.5858585858585859, 0.595959595959596, 0.6060606060606061, 0.6161616161616162, 0.6262626262626263, 0.6363636363636365, 0.6464646464646465, 0.6565656565656566, 0.6666666666666667, 0.6767676767676768, 0.686868686868687, 0.696969696969697, 0.7070707070707072, 0.7171717171717172, 0.7272727272727273, 0.7373737373737375, 0.7474747474747475, 0.7575757575757577, 0.7676767676767677, 0.7777777777777778, 0.787878787878788, 0.797979797979798, 0.8080808080808082, 0.8181818181818182, 0.8282828282828284, 0.8383838383838385, 0.8484848484848485, 0.8585858585858587, 0.8686868686868687, 0.8787878787878789, 0.888888888888889, 0.8989898989898991, 0.9090909090909092, 0.9191919191919192, 0.9292929292929294, 0.9393939393939394, 0.9494949494949496, 0.9595959595959597, 0.9696969696969697, 0.9797979797979799, 0.98989898989899, 1.0], "y": [3.9623568244974257, 5.59365815715703, 6.102680622168492, 4.487822268824424, 4.734580140302545, 3.3829939864921883, 4.728485511420428, 5.945554250031659, 4.373007213314565, 4.734052718056487, 5.687293575189152, 7.048456908637855, 4.538441048186675, 5.687847423168455, 6.00812262256532, 4.843491018426125, 5.900077530374725, 6.000471322140927, 5.688374960247316, 3.1189042387372545, 5.859958148933172, 5.92045267748011, 5.270603246468369, 5.027819141649983, 2.8127423886446943, 5.134743775497379, 4.318544353923637, 2.577608938692351, 5.421173751836292, 4.322665354254515, 3.8597855763685898, 5.284615961239685, 4.457758597421851, 5.463519461503606, 4.1383119436689535, 5.8745422712420226, 4.455741457932556, 5.369966062639821, 4.565058772422818, 6.110123049123135, 3.6386332411614033, 4.864486324938091, 4.447977799800293, 4.950470775286345, 5.887307752015507, 6.154646723315321, 5.115766954170989, 3.838479672389576, 4.815368462077817, 5.466984070663726, 2.999014469238763, 3.652241541456256, 4.779371847210642, 4.921033624959668, 4.39215278183303, 3.7542661222313978, 6.629794317758779, 5.177528567116626, 4.328013422053625, 5.331128138937101, 7.006042774550741, 5.0061448421051935, 3.465309390584875, 4.930336576372079, 5.227687821018511, 2.487383266330429, 7.702712505968621, 5.58365058076347, 5.338781748592111, 5.689001408268186, 6.700348675458416, 4.558732757505499, 5.314493800301297, 5.636297587454268, 5.086771378076907, 4.882208369832598, 3.724126565435677, 5.906755961687117, 5.006062617766832, 4.147896360899007, 5.499587436442585, 3.4871907342782507, 7.004290632975638, 6.25882568579033, 6.040154873274862, 6.0513821040268425, 5.971570159583026, 3.413608859269023, 4.489418150856028, 4.121027062594841, 3.8644799238689185, 5.497006777318358, 6.510225865307171, 5.92073363775182, 5.639412012922287, 6.217040385050823, 5.15525235849528, 5.009229 ...

# %% [markdown]
# ## Donut charts

# %%
mylabels = ['Pie','Donut','Apple Fritter']
myvalues = [45,25,7]

trace1 = go.Pie(
    hole=0.1,
    sort=False,
    values=myvalues,
    labels=mylabels,
    textinfo='labels',
    textposition='inside',
    marker={'colors': ['darkgreen', 'lightgreen', 'blue'],
            'line': {'color': 'white', 'width': 5}}
)
mylayout = go.Layout(
    title = 'Never use graphs named after desserts!'
)
fig = go.Figure(data=[trace1], layout=mylayout)
iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-cd7297b7d737> in <module>
#      10     textposition='inside',
#      11     marker={'colors': ['darkgreen', 'lightgreen', 'blue'],
# ---> 12             'line': {'color': 'white', 'width': 5}}
#      13 )
#      14 mylayout = go.Layout(
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/graph_objs/__init__.py in __init__(self, arg, customdata, customdatasrc, direction, dlabel, domain, hole, hoverinfo, hoverinfosrc, hoverlabel, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, insidetextfont, label0, labels, labelssrc, legendgroup, marker, name, opacity, outsidetextfont, pull, pullsrc, rotation, scalegroup, showlegend, sort, stream, text, textfont, textinfo, textposition, textpositionsrc, textsrc, title, titlefont, titleposition, uid, uirevision, values, valuessrc, visible, **kwargs)
#   41671         self['textfont'] = textfont if textfont is not None else _v
#   41672         _v = arg.pop('textinfo', None)
# > 41673         self['textinfo'] = textinfo if textinfo is not None else _v
#   41674         _v = arg.pop('textposition', None)
#   41675         self['textposition'] = textposition if textposition is not None else _v
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/basedatatypes.py in __setitem__(self, prop, value)
#    2887             # ### Handle simple property ###
#    2888             else:
# -> 2889                 self._set_prop(prop, value)
#    2890
#    2891         # Handle non-scalar case
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/basedatatypes.py in _set_prop(self, prop, val)
#    3128                 return
#    3129             else:
# -> 3130                 raise err
#    3131
#    3132         # val is None
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/basedatatypes.py in _set_prop(self, prop, val)
#    3123         validator = self._validators.get(prop)
#    3124         try:
# -> 3125             val = validator.validate_coerce(val)
#    3126         except ValueError as err:
#    3127             if self._skip_invalid:
#
# ~/anaconda3/lib/python3.6/site-packages/_plotly_utils/basevalidators.py in validate_coerce(self, v)
#    1601             validated_v = self.vc_scalar(v)
#    1602             if validated_v is None:
# -> 1603                 self.raise_invalid_val(v)
#    1604
#    1605             v = validated_v
#
# ~/anaconda3/lib/python3.6/site-packages/_plotly_utils/basevalidators.py in raise_invalid_val(self, v, inds)
#     275             typ=type_str(v),
#     276             v=repr(v),
# --> 277             valid_clr_desc=self.description()))
#     278
#     279     def raise_invalid_elements(self, invalid_els):
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'textinfo' property of pie
#         Received value: 'labels'
#
#     The 'textinfo' property is a flaglist and may be specified
#     as a string containing:
#       - Any combination of ['label', 'text', 'value', 'percent'] joined with '+' characters
#         (e.g. 'label+text')
#         OR exactly one of ['none'] (e.g. 'none')

# %%
# Notice that in this example, we don't use the plotly "go" functions.

fig = {
  "data": [
    {
      "values": [16, 15, 12, 6, 5, 4, 42],
      "labels": [
        "US",
        "China",
        "European Union",
        "Russian Federation",
        "Brazil",
        "India",
        "Rest of World"
      ],
      "domain": {"x": [0, .48]},
      "name": "GHG Emissions",
      "hoverinfo":"label+percent+name",
      "hole": .1,
      "type": "pie"
    },
    {
      "values": [27, 11, 25, 8, 1, 3, 25],
      "labels": [
        "US",
        "China",
        "European Union",
        "Russian Federation",
        "Brazil",
        "India",
        "Rest of World"
      ],
      "text":["CO2"],
      "textposition":"inside",
      "domain": {"x": [.52, 1]},
      "name": "CO2 Emissions",
      "hoverinfo":"label+percent+name",
      "hole": .4,
      "type": "pie"
    }],
  "layout": {
        "title":"Global Emissions 1990-2011",
        "annotations": [
            {
                "font": {
                    "size": 20
                },
                "showarrow": False,
                "text": "GHG",
                "x": 0.20,
                "y": 0.5
            },
            {
                "font": {
                    "size": 20
                },
                "showarrow": False,
                "text": "CO2",
                "x": 0.8,
                "y": 0.5
            }
        ]
    }
}
iplot(fig)
# Out:
# <div>
#
#
#             <div id="4f130e9f-d78a-4ad5-b15d-63c0b09cc510" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4f130e9f-d78a-4ad5-b15d-63c0b09cc510")) {
#                     Plotly.newPlot(
#                         '4f130e9f-d78a-4ad5-b15d-63c0b09cc510',
#                         [{"domain": {"x": [0, 0.48]}, "hole": 0.1, "hoverinfo": "label+percent+name", "labels": ["US", "China", "European Union", "Russian Federation", "Brazil", "India", "Rest of World"], "name": "GHG Emissions", "type": "pie", "uid": "cfce379f-d9f7-4529-bafb-ffb18852306c", "values": [16, 15, 12, 6, 5, 4, 42]}, {"domain": {"x": [0.52, 1]}, "hole": 0.4, "hoverinfo": "label+percent+name", "labels": ["US", "China", "European Union", "Russian Federation", "Brazil", "India", "Rest of World"], "name": "CO2 Emissions", "text": ["CO2"], "textposition": "inside", "type": "pie", "uid": "7706fb64-3396-49b4-9c87-f6b6a3851fee", "values": [27, 11, 25, 8, 1, 3, 25]}],
#                         {"annotations": [{"font": {"size": 20}, "showarrow": false, "text": "GHG", "x": 0.2, "y": 0.5}, {"font": {"size": 20}, "showarrow": false, "text": "CO2", "x": 0.8, "y": 0.5}], "title": {"text": "Global Emissions 1990-2011"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('4f130e9f-d78a-4ad5-b15d-63c0b09cc510');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
