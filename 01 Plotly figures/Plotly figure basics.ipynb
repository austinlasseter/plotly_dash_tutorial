500325405047, -0.16439673162128768, -0.03743329548456323, 0.27316727202588537, -0.6556434137851039, -0.896572871098125, 0.5850857207497607, 0.6689627443973413, -0.2537186049965116, -0.7306167268485422, 1.0781013342156864, 0.571728367872354, -0.9595021592175621, -0.5197075580688302, -0.7517275661917049, 0.5084719070819772, -0.6634657312166905, 0.3822162348430252, 1.4856856574360964, -0.858285804327042, 0.1213470326106138, -0.8325580323310073, 0.2603444750392247, 0.14830588840144146, -0.3986770859223169, -0.5494554899225977, -0.24917126605281112, 0.8473262568021128, -0.7196749930047459, -0.9939755413618085, 0.9063556038773094, 0.6377343366413664, 0.46344507910539795, -0.7871950165751057, 0.10802815804496255, -0.32253794175491496, 0.5680649470488419, -0.36110374935857437, 0.27607148614281257, -0.06936796943926518, -2.0806739691811056, 1.366793186768717, 1.5475863272888541, 0.932658270620785, 1.2542099538816027, 0.2515359878263734, -1.6249905966852694, -1.3248420579455038, 0.6567650195202803, 1.8777589130041648, 0.4631364482531453, 0.2067824917690761, -0.07508454159735711, 0.5262737913838534, -0.6522937008236093, -0.10796633432015329, -1.8659169569083247, 0.2944779864261902, -0.630287311558818, 1.0711367231601217, 1.7578776492758574, -0.10286475868521158, 0.49489732537844056, 0.37677423866230547, -0.06612305630193879, -0.1145990816737218, 0.364725325559618, 1.3531977149597105, -0.47996985814813725, -0.009861266121536084, 0.2846760036742308, 0.15983978486897726, 0.7677579560917153, -1.315352678235348, 1.6137463255602171, 0.06109850530446138, -0.4276487824502896, 2.134567054453679, -2.241768461817994, 0.25437979642225944, 0.44534562036856123, -0.624314222094497, 0.4928809986480598, 0.5269243535238822, 1.3436612393613419, -1.2620963829563898, -0.711026333981296, 0.1351422676124069, 2.6438992485752193, -1.502042217495799, -0.4807388829967842, 1.3683913222929884, 0.0806765777176454, -0.6170136418695954, 0.007287251791662318, -1.432146417529671, 0.22566680821871327, 0.7212411466388232, 2.1739547952121088, 1.85580 ...

# %% [markdown]
# ## How it works

# %%
# Define our data as lists.
x_values=['giraffes', 'orangutans', 'monkeys']
y_values=[20, 14, 23]

# %%
# Plotly's 'go.Bar' function will create a dictionary of our x and y values, with predefined keys. 
go.Bar(x=x_values, y=y_values)
# Out:
# {'type': 'bar', 'x': ['giraffes', 'orangutans', 'monkeys'], 'y': [20, 14, 23]}

# %%
# You'll always have to place your data dictionary inside a list
# because it will become a component of a larger dictionary once we read it into Plotly's 'go.Figure' function
[go.Bar(x=x_values, y=y_values)]
# Out:
# [{'type': 'bar',
#   'x': ['giraffes', 'orangutans', 'monkeys'],
#   'y': [20, 14, 23]}]

# %%
# Define our axis labels as dictionaries.
x_title = {'title': 'Type of animal'} 
y_title = {'title': 'Number in the zoo'} 
print(x_title, y_title)
# Out:
# {'title': 'Type of animal'} {'title': 'Number in the zoo'}

# %%
# You can do the same thing using Python's 'dict' function
x_title = dict(title = 'Type of animal')
y_title = dict(title = 'Number in the zoo')
print(x_title, y_title)
# Out:
# {'title': 'Type of animal'} {'title': 'Number in the zoo'}

# %%
# Plotly's 'go.Layout' function will create a dictionary of our axis labels, with predefined keys.
go.Layout(xaxis=x_title, yaxis=y_title)
# Out:
# {'xaxis': {'title': 'Type of animal'}, 'yaxis': {'title': 'Number in the zoo'}}

# %%
# Plotly's 'go.Figure' function will create a dictionary of our axis labels, with predefined keys.
my_data = [go.Bar(go.Bar(x=x_values, y=y_values))] # Note: We have to put the data dictionary inside a list!
my_layout = go.Layout(xaxis=x_title, yaxis=y_title)
go.Figure(data=my_data, layout=my_layout)
# Out:
# {'data': [{'type': 'bar',
#    'x': ['giraffes', 'orangutans', 'monkeys'],
#    'y': [20, 14, 23]}],
#  'layout': {'xaxis': {'title': 'Type of animal'},
#   'yaxis': {'title': 'Number in the zoo'}}}

# %%
# Finally, display your figure 
fig = go.Figure(data=my_data, layout=my_layout)
iplot(fig) # inside the Jupyter notebook
plot(fig) # in your browswer
# Out:
# <div id="f12768bc-ab3c-4159-be6f-c21751379935" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f12768bc-ab3c-4159-be6f-c21751379935", [{"type": "bar", "x": ["giraffes", "orangutans", "monkeys"], "y": [20, 14, 23]}], {"xaxis": {"title": "Type of animal"}, "yaxis": {"title": "Number in the zoo"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# 'file:///Users/austinlasseter/atelier/schoolhouse/plotly_dash_tutorial/01 Plotly figures/temp-plot.html'

# %% [markdown]
# ## Formatting a simple bar chart

# %%
# Adding some layout to the simple chart we saw before
data = [go.Bar(
            x=['giraffes', 'orangutans', 'monkeys'],
            y=[20, 14, 23],
            marker=dict(color='green')
    )]

layout = go.Layout(
    title = 'My favorite animals', # Graph title
    xaxis = dict(title = 'Type of animal'), # x-axis label
    yaxis = dict(title = 'Number in the zoo'), # y-axis label
    
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="1beeaf06-b311-42e4-917c-226a73facac7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1beeaf06-b311-42e4-917c-226a73facac7", [{"type": "bar", "x": ["giraffes", "orangutans", "monkeys"], "y": [20, 14, 23], "marker": {"color": "green"}}], {"title": "My favorite animals", "xaxis": {"title": "Type of animal"}, "yaxis": {"title": "Number in the zoo"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# Grouped bar chart
trace1 = go.Bar(
    x=['giraffes', 'orangutans', 'monkeys'],
    y=[20, 14, 23],
    name='SF Zoo',
    marker=dict(color='rgb(10,10,255)')
)
trace2 = go.Bar(
    x=['giraffes', 'orangutans', 'monkeys'],
    y=[12, 18, 29],
    name='LA Zoo',
    marker=dict(color='rgb(139,0,0)')
)

data = [trace1, trace2]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="09f100cb-960e-48f9-ba9a-bdba3446701f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("09f100cb-960e-48f9-ba9a-bdba3446701f", [{"type": "bar", "x": ["giraffes", "orangutans", "monkeys"], "y": [20, 14, 23], "name": "SF Zoo", "marker": {"color": "rgb(10,10,255)"}}, {"type": "bar", "x": ["giraffes", "orangutans", "monkeys"], "y": [12, 18, 29], "name": "LA Zoo", "marker": {"color": "rgb(139,0,0)"}}], {"barmode": "group"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# Stacked bar chart
trace1 = go.Bar(
    x=['giraffes', 'orangutans', 'monkeys'],
    y=[20, 14, 23],
    name='SF Zoo',
    textposition = 'auto',
    marker=dict(
        color='lightgreen',
        line=dict(
            color='darkblue',
            width=1.5),
        ),
    opacity=0.6
)
trace2 = go.Bar(
    x=['giraffes', 'orangutans', 'monkeys'],
    y=[12, 18, 29],
    name='LA Zoo',
    textposition = 'auto',
    marker=dict(
        color='lightblue',
        line=dict(
            color='darkblue',
            width=1.5),
        ),
    opacity=0.6
)

data = [trace1, trace2]
layout = go.Layout(
    barmode='stack',
    title = 'My favorite animals', # Graph title
    xaxis = dict(title = 'Type of animal', tickangle=-45), # x-axis label
    yaxis = dict(title = 'Number in the zoo'), # y-axis label
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="ca1b858d-672e-495e-9169-6e4544923cc4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ca1b858d-672e-495e-9169-6e4544923cc4", [{"type": "bar", "x": ["giraffes", "orangutans", "monkeys"], "y": [20, 14, 23], "name": "SF Zoo", "textposition": "auto", "marker": {"color": "lightgreen", "line": {"color": "darkblue", "width": 1.5}}, "opacity": 0.6}, {"type": "bar", "x": ["giraffes", "orangutans", "monkeys"], "y": [12, 18, 29], "name": "LA Zoo", "textposition": "auto", "marker": {"color": "lightblue", "line": {"color": "darkblue", "width": 1.5}}, "opacity": 0.6}], {"barmode": "stack", "title": "My favorite animals", "xaxis": {"title": "Type of animal", "tickangle": -45}, "yaxis": {"title": "Number in the zoo"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ## Simple scatter plot

# %%
# Create some fake data.
np.random.seed(42)
random_x = np.random.randint(1,101,100)
random_y = np.random.randint(1,101,100)

# %%
# Visualize the data with Plotly Graph Objects library
data = [go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers'
)]

fig =go.Figure(data=data)
iplot(fig) # This will visualize your figure within the Jupyter noteobook
# py.plot(data) # Note: This will publish your figure to the web via Plotly, but requires an account.
# Out:
# <div id="7acd6721-0cee-4a8d-8e2f-1de86f4b3f7e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7acd6721-0cee-4a8d-8e2f-1de86f4b3f7e", [{"type": "scatter", "x": [52, 93, 15, 72, 61, 21, 83, 87, 75, 75, 88, 100, 24, 3, 22, 53, 2, 88, 30, 38, 2, 64, 60, 21, 33, 76, 58, 22, 89, 49, 91, 59, 42, 92, 60, 80, 15, 62, 62, 47, 62, 51, 55, 64, 3, 51, 7, 21, 73, 39, 18, 4, 89, 60, 14, 9, 90, 53, 2, 84, 92, 60, 71, 44, 8, 47, 35, 78, 81, 36, 50, 4, 2, 6, 54, 4, 54, 93, 63, 18, 90, 44, 34, 74, 62, 100, 14, 95, 48, 15, 72, 78, 87, 62, 40, 85, 80, 82, 53, 24], "y": [26, 89, 60, 41, 29, 15, 45, 65, 89, 71, 9, 88, 1, 8, 88, 63, 11, 81, 8, 35, 35, 33, 5, 41, 28, 7, 73, 72, 12, 34, 33, 48, 23, 62, 88, 37, 99, 44, 86, 91, 35, 65, 99, 47, 78, 3, 1, 5, 90, 14, 27, 9, 79, 15, 90, 42, 77, 51, 63, 96, 52, 96, 4, 94, 23, 15, 43, 29, 36, 13, 32, 71, 59, 86, 28, 66, 42, 45, 62, 57, 6, 28, 28, 44, 84, 30, 62, 75, 92, 89, 62, 97, 1, 27, 62, 77, 3, 70, 72, 27], "mode": "markers"}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# Let's add some layout to our data.
data = [go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers',
    marker=dict(
        color='rgb(58,200,225)')
)]
layout = go.Layout(
    title = 'Random Data Scatterplot', # Graph title
    xaxis = dict(title = 'Some random x-values'), # x-axis label
    yaxis = dict(title = 'Some random y-values'), # y-axis label
    hovermode ='closest' # handles multiple points landing on the same vertical
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="4bd5d355-9e8b-4a01-861c-28da5e8241e0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4bd5d355-9e8b-4a01-861c-28da5e8241e0", [{"type": "scatter", "x": [52, 93, 15, 72, 61, 21, 83, 87, 75, 75, 88, 100, 24, 3, 22, 53, 2, 88, 30, 38, 2, 64, 60, 21, 33, 76, 58, 22, 89, 49, 91, 59, 42, 92, 60, 80, 15, 62, 62, 47, 62, 51, 55, 64, 3, 51, 7, 21, 73, 39, 18, 4, 89, 60, 14, 9, 90, 53, 2, 84, 92, 60, 71, 44, 8, 47, 35, 78, 81, 36, 50, 4, 2, 6, 54, 4, 54, 93, 63, 18, 90, 44, 34, 74, 62, 100, 14, 95, 48, 15, 72, 78, 87, 62, 40, 85, 80, 82, 53, 24], "y": [26, 89, 60, 41, 29, 15, 45, 65, 89, 71, 9, 88, 1, 8, 88, 63, 11, 81, 8, 35, 35, 33, 5, 41, 28, 7, 73, 72, 12, 34, 33, 48, 23, 62, 88, 37, 99, 44, 86, 91, 35, 65, 99, 47, 78, 3, 1, 5, 90, 14, 27, 9, 79, 15, 90, 42, 77, 51, 63, 96, 52, 96, 4, 94, 23, 15, 43, 29, 36, 13, 32, 71, 59, 86, 28, 66, 42, 45, 62, 57, 6, 28, 28, 44, 84, 30, 62, 75, 92, 89, 62, 97, 1, 27, 62, 77, 3, 70, 72, 27], "mode": "markers", "marker": {"color": "rgb(58,200,225)"}}], {"title": "Random Data Scatterplot", "xaxis": {"title": "Some random x-values"}, "yaxis": {"title": "Some random y-values"}, "hovermode": "closest"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
data = [go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers',
    marker = dict(      # change the marker style
        size = 12,
        color = 'rgb(51,204,153)',
        symbol = 'pentagon',
        line = dict(
            width = 2,
        )
    )
)]
layout = go.Layout(
    title = 'Random Data Scatterplot', # Graph title
    xaxis = dict(title = 'Some random x-values'), # x-axis label
    yaxis = dict(title = 'Some random y-values'), # y-axis label
    hovermode ='closest' # handles multiple points landing on the same vertical
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="59632062-53c6-4885-92f7-1ae541833394" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("59632062-53c6-4885-92f7-1ae541833394", [{"type": "scatter", "x": [52, 93, 15, 72, 61, 21, 83, 87, 75, 75, 88, 100, 24, 3, 22, 53, 2, 88, 30, 38, 2, 64, 60, 21, 33, 76, 58, 22, 89, 49, 91, 59, 42, 92, 60, 80, 15, 62, 62, 47, 62, 51, 55, 64, 3, 51, 7, 21, 73, 39, 18, 4, 89, 60, 14, 9, 90, 53, 2, 84, 92, 60, 71, 44, 8, 47, 35, 78, 81, 36, 50, 4, 2, 6, 54, 4, 54, 93, 63, 18, 90, 44, 34, 74, 62, 100, 14, 95, 48, 15, 72, 78, 87, 62, 40, 85, 80, 82, 53, 24], "y": [26, 89, 60, 41, 29, 15, 45, 65, 89, 71, 9, 88, 1, 8, 88, 63, 11, 81, 8, 35, 35, 33, 5, 41, 28, 7, 73, 72, 12, 34, 33, 48, 23, 62, 88, 37, 99, 44, 86, 91, 35, 65, 99, 47, 78, 3, 1, 5, 90, 14, 27, 9, 79, 15, 90, 42, 77, 51, 63, 96, 52, 96, 4, 94, 23, 15, 43, 29, 36, 13, 32, 71, 59, 86, 28, 66, 42, 45, 62, 57, 6, 28, 28, 44, 84, 30, 62, 75, 92, 89, 62, 97, 1, 27, 62, 77, 3, 70, 72, 27], "mode": "markers", "marker": {"size": 12, "color": "rgb(51,204,153)", "symbol": "pentagon", "line": {"width": 2}}}], {"title": "Random Data Scatterplot", "xaxis": {"title": "Some random x-values"}, "yaxis": {"title": "Some random y-values"}, "hovermode": "closest"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# Using colorscale
trace1 = go.Scatter(
    y = np.random.randn(500),
    mode='markers',
    marker=dict(
        size=16,
        color = np.random.randn(500), #set color equal to a third variable
        colorscale='Viridis',
        showscale=True
    )
)
data = [trace1]
layout = go.Layout(
    title = 'Random Data Scatterplot', # Graph title
    xaxis = dict(title = 'Some random x-values'), # x-axis label
    yaxis = dict(title = 'Some random y-values'), # y-axis label
    hovermode ='closest' # handles multiple points landing on the same vertical
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="9a41517d-45e1-47fa-953d-2331679132e7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9a41517d-45e1-47fa-953d-2331679132e7", [{"type": "scatter", "y": [-1.4153707420504142, -0.42064532276535904, -0.3427145165267695, -0.8022772692216189, -0.16128571166600914, 0.4040508568145384, 1.8861859012105302, 0.17457781283183896, 0.25755039072276437, -0.07444591576616721, -1.9187712152990415, -0.026513875449216878, 0.06023020994102644, 2.463242112485286, -0.19236096478112252, 0.30154734233361247, -0.03471176970524331, -1.168678037619532, 1.1428228145150205, 0.7519330326867741, 0.7910319470430469, -0.9093874547947389, 1.4027943109360992, -1.4018510627922809, 0.5868570938002703, 2.1904556258099785, -0.9905363251306883, -0.5662977296027719, 0.09965136508764122, -0.5034756541161992, -1.5506634310661327, 0.06856297480602733, -1.0623037137261049, 0.4735924306351816, -0.9194242342338032, 1.5499344050175394, -0.7832532923362371, -0.3220615162056756, 0.8135172173696698, -1.2308643164339552, 0.22745993460412942, 1.307142754282428, -1.6074832345612275, 0.1846338585323042, 0.25988279424842353, 0.7818228717773104, -1.236950710878082, -1.3204566130842763, 0.5219415656168976, 0.29698467323318606, 0.25049285034587654, 0.3464482094969757, -0.6800247215784908, 0.23225369716100355, 0.29307247329868125, -0.7143514180263678, 1.8657745111447566, 0.4738329209117875, -1.1913034972026486, 0.6565536086338297, -0.9746816702273214, 0.787084603742452, 1.158595579007404, -0.8206823183517105, 0.9633761292443218, 0.4127809269364983, 0.82206015999449, 1.8967929826539474, -0.2453881160028705, -0.7537361643574896, -0.8895144296255233, -0.8158102849654383, -0.0771017094141042, 0.3411519748166439, 0.27669079933001905, 0.8271832490360238, 0.01300189187790702, 1.4535340771573169, -0.2646568332379561, 2.720169166589619, 0.6256673477650062, -0.8571575564162826, -1.0708924980611123, 0.4824724152431853, -0.2234627853258509, 0.714000494092092, 0.47323762457354485, -0.07282891265687277, -0.846793718068405, -1.5148472246858646, -0.4465149520670211, 0.8563987943234723, 0.21409374413020396, -1.245738778711988, 0.173180925851182, 0.3853173797288368, -0.883857436201133, 0.1537251059455279, 0.058208718445999896, -1.142970297830623, 0.3577873603482833, 0.5607845263682344, 1.083051243175277, 1.053802052034903, -1.377669367957091, -0.9378250399151228, 0.5150352672086598, 0.5137859509122088, 0.5150476863060479, 3.852731490654721, 0.570890510693167, 1.135565640180599, 0.9540017634932023, 0.651391251305798, -0.3152692446403456, 0.7589692204932674, -0.7728252145375718, -0.23681860674000887, -0.48536354782910346, 0.08187413938632256, 2.3146585666735087, -1.867265192591748, 0.6862601903745135, -1.6127158711896517, -0.47193186578943347, 1.088950596967366, 0.06428001909546277, -1.0777447779293061, -0.7153037092599682, 0.6795977489346758, -0.7303666317171367, 0.21645858958197486, 0.045571839903813784, -0.6516003476058171, 2.1439440893253257, 0.6339190223180112, -2.025142586657607, 0.18645431476942764, -0.661786464768388, 0.852433334796224, -0.7925207384327007, -0.11473644146689901, 0.5049872789804571, 0.8657551941701215, -1.2002964070557762, -0.3345012358409484, -0.4749453111609562, -0.6533292325737119, 1.7654542402810969, 0.40498171096095553, -1.2608839543350452, 0.9178619470547761, 2.1221561970126332, 1.0324652605511468, -1.5193699659540134, -0.48423407286625136, 1.2669111491866227, -0.7076694656187807, 0.44381942814622843, 0.7746340534293368, -0.926930471578083, -0.05952535606180008, -3.2412673400690726, -1.0243876413342898, -0.2525681513931603, -1.2477831819648495, 1.6324113039316352, -1.4301413779606327, -0.44004448669698376, 0.13074057728609134, 1.4412732890661155, -1.4358621511794394, 1.1631637521549596, 0.010233061019587049, -0.9815086510479509, 0.46210347426327075, 0.19905969557347003, -0.60021687 ...

# %% [markdown]
# ## Line Plot

# %%
# create some random data
np.random.seed(56)
x_values = np.linspace(0, 1, 100) # 100 evenly spaced values
y_values = np.random.randn(100)   # 100 random values

# create traces
trace0 = go.Scatter(
    x = x_values,
    y = y_values+5,
    mode = 'markers',
    name = 'markers'
)
trace1 = go.Scatter(
    x = x_values,
    y = y_values,
    mode = 'lines+markers',
    name = 'lines+markers'
)
trace2 = go.Scatter(
    x = x_values,
    y = y_values-5,
    mode = 'lines',
    name = 'lines'
)

# assign traces to data
data = [trace0, trace1, trace2]  
layout = go.Layout(
    title = 'Line chart showing three different modes'
)
# Generate the figure dictionary
fig = go.Figure(data=data,layout=layout)

# Display the figure
iplot(fig)
# Out:
# <div id="4d3be87f-4790-4b40-af53-e49ed863084c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4d3be87f-4790-4b40-af53-e49ed863084c", [{"type": "scatter", "x": [0.0, 0.010101010101010102, 0.020202020202020204, 0.030303030303030304, 0.04040404040404041, 0.05050505050505051, 0.06060606060606061, 0.07070707070707072, 0.08080808080808081, 0.09090909090909091, 0.10101010101010102, 0.11111111111111112, 0.12121212121212122, 0.13131313131313133, 0.14141414141414144, 0.15151515151515152, 0.16161616161616163, 0.17171717171717174, 0.18181818181818182, 0.19191919191919193, 0.20202020202020204, 0.21212121212121213, 0.22222222222222224, 0.23232323232323235, 0.24242424242424243, 0.25252525252525254, 0.26262626262626265, 0.27272727272727276, 0.2828282828282829, 0.29292929292929293, 0.30303030303030304, 0.31313131313131315, 0.32323232323232326, 0.33333333333333337, 0.3434343434343435, 0.3535353535353536, 0.36363636363636365, 0.37373737373737376, 0.38383838383838387, 0.393939393939394, 0.4040404040404041, 0.4141414141414142, 0.42424242424242425, 0.43434343434343436, 0.4444444444444445, 0.4545454545454546, 0.4646464646464647, 0.4747474747474748, 0.48484848484848486, 0.494949494949495, 0.5050505050505051, 0.5151515151515152, 0.5252525252525253, 0.5353535353535354, 0.5454545454545455, 0.5555555555555556, 0.5656565656565657, 0.5757575757575758, 0.5858585858585859, 0.595959595959596, 0.6060606060606061, 0.6161616161616162, 0.6262626262626263, 0.6363636363636365, 0.6464646464646465, 0.6565656565656566, 0.6666666666666667, 0.6767676767676768, 0.686868686868687, 0.696969696969697, 0.7070707070707072, 0.7171717171717172, 0.7272727272727273, 0.7373737373737375, 0.7474747474747475, 0.7575757575757577, 0.7676767676767677, 0.7777777777777778, 0.787878787878788, 0.797979797979798, 0.8080808080808082, 0.8181818181818182, 0.8282828282828284, 0.8383838383838385, 0.8484848484848485, 0.8585858585858587, 0.8686868686868687, 0.8787878787878789, 0.888888888888889, 0.8989898989898991, 0.9090909090909092, 0.9191919191919192, 0.9292929292929294, 0.9393939393939394, 0.9494949494949496, 0.9595959595959597, 0.9696969696969697, 0.9797979797979799, 0.98989898989899, 1.0], "y": [3.9623568244974257, 5.59365815715703, 6.102680622168492, 4.487822268824424, 4.734580140302545, 3.3829939864921883, 4.728485511420428, 5.945554250031659, 4.373007213314565, 4.734052718056487, 5.687293575189152, 7.048456908637855, 4.538441048186675, 5.687847423168455, 6.00812262256532, 4.843491018426125, 5.900077530374725, 6.000471322140927, 5.688374960247316, 3.1189042387372545, 5.859958148933172, 5.92045267748011, 5.270603246468369, 5.027819141649983, 2.8127423886446943, 5.134743775497379, 4.318544353923637, 2.577608938692351, 5.421173751836292, 4.322665354254515, 3.8597855763685898, 5.284615961239685, 4.457758597421851, 5.463519461503606, 4.1383119436689535, 5.8745422712420226, 4.455741457932556, 5.369966062639821, 4.565058772422818, 6.110123049123135, 3.6386332411614033, 4.864486324938091, 4.447977799800293, 4.950470775286345, 5.887307752015507, 6.154646723315321, 5.115766954170989, 3.838479672389576, 4.815368462077817, 5.466984070663726, 2.999014469238763, 3.652241541456256, 4.779371847210642, 4.921033624959668, 4.39215278183303, 3.7542661222313978, 6.629794317758779, 5.177528567116626, 4.328013422053625, 5.331128138937101, 7.006042774550741, 5.0061448421051935, 3.465309390584875, 4.930336576372079, 5.227687821018511, 2.487383266330429, 7.702712505968621, 5.58365058076347, 5.338781748592111, 5.689001408268186, 6.700348675458416, 4.558732757505499, 5.314493800301297, 5.636297587454268, 5.086771378076907, 4.882208369832598, 3.724126565435677, 5.906755961687117, 5.006062617766832, 4.147896360899007, 5.499587436442585, 3.4871907342782507, 7.004290632975638, 6.25882568579033, 6.040154873274862, 6.0513821040268425, 5. ...

# %% [markdown]
# ## Donut charts

# %%
mylabels = ['Pie','Donut','Apple Fritter']
myvalues = [45,25,7]

trace1 = go.Pie(
    hole=0.5,
    sort=False,
    values=myvalues,
    labels=mylabels,
    textinfo='labels',
    textposition='inside',
    marker={'colors': ['darkgreen', 'lightgreen', 'blue'],
            'line': {'color': 'white', 'width': 5}}
)
mylayout = go.Layout(
    title = 'Never use graphs named after desserts!'
)
fig = go.Figure(data=[trace1], layout=mylayout)
iplot(fig)
# Out:
# <div id="0be05b7e-cb67-48dc-bb32-c25562323e32" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0be05b7e-cb67-48dc-bb32-c25562323e32", [{"type": "pie", "hole": 0.5, "sort": false, "values": [45, 25, 7], "labels": ["Pie", "Donut", "Apple Fritter"], "textinfo": "labels", "textposition": "inside", "marker": {"colors": ["darkgreen", "lightgreen", "blue"], "line": {"color": "white", "width": 5}}}], {"title": "Never use graphs named after desserts!"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# Notice that in this example, we don't use the plotly "go" functions.

fig = {
  "data": [
    {
      "values": [16, 15, 12, 6, 5, 4, 42],
      "labels": [
        "US",
        "China",
        "European Union",
        "Russian Federation",
        "Brazil",
        "India",
        "Rest of World"
      ],
      "domain": {"x": [0, .48]},
      "name": "GHG Emissions",
      "hoverinfo":"label+percent+name",
      "hole": .4,
      "type": "pie"
    },
    {
      "values": [27, 11, 25, 8, 1, 3, 25],
      "labels": [
        "US",
        "China",
        "European Union",
        "Russian Federation",
        "Brazil",
        "India",
        "Rest of World"
      ],
      "text":["CO2"],
      "textposition":"inside",
      "domain": {"x": [.52, 1]},
      "name": "CO2 Emissions",
      "hoverinfo":"label+percent+name",
      "hole": .4,
      "type": "pie"
    }],
  "layout": {
        "title":"Global Emissions 1990-2011",
        "annotations": [
            {
                "font": {
                    "size": 20
                },
                "showarrow": False,
                "text": "GHG",
                "x": 0.20,
                "y": 0.5
            },
            {
                "font": {
                    "size": 20
                },
                "showarrow": False,
                "text": "CO2",
                "x": 0.8,
                "y": 0.5
            }
        ]
    }
}
iplot(fig)
# Out:
# <div id="3d9cce1f-1232-43ee-9f93-09689ed77c87" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3d9cce1f-1232-43ee-9f93-09689ed77c87", [{"values": [16, 15, 12, 6, 5, 4, 42], "labels": ["US", "China", "European Union", "Russian Federation", "Brazil", "India", "Rest of World"], "domain": {"x": [0, 0.48]}, "name": "GHG Emissions", "hoverinfo": "label+percent+name", "hole": 0.4, "type": "pie"}, {"values": [27, 11, 25, 8, 1, 3, 25], "labels": ["US", "China", "European Union", "Russian Federation", "Brazil", "India", "Rest of World"], "text": ["CO2"], "textposition": "inside", "domain": {"x": [0.52, 1]}, "name": "CO2 Emissions", "hoverinfo": "label+percent+name", "hole": 0.4, "type": "pie"}], {"title": "Global Emissions 1990-2011", "annotations": [{"font": {"size": 20}, "showarrow": false, "text": "GHG", "x": 0.2, "y": 0.5}, {"font": {"size": 20}, "showarrow": false, "text": "CO2", "x": 0.8, "y": 0.5}]}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
